# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
rhpass=pd.read_csv("attack_freebsd_tcpdump.csv", parse_dates=['Time'])
rhpass.head()
# Out:
#    No.                Time             Source        Destination Protocol  \
# 0    1 2011-11-18 10:42:32        10.10.10.15       10.10.10.255  BROWSER
# 1    2 2011-11-18 10:43:14      3com_68:a6:95          Broadcast      ARP
# 2    3 2011-11-18 10:43:46        10.10.10.10        224.0.0.251     MDNS
# 3    4 2011-11-18 10:44:04  Tp-LinkT_b5:79:3f          Broadcast      ARP
# 4    5 2011-11-18 10:44:04      3com_68:a6:95  Tp-LinkT_b5:79:3f      ARP
#
#    Length                                               Info
# 0     243  Local Master Announcement XP, Workstation, Ser...
# 1      60              Who has 10.10.10.10?  Tell 10.10.10.1
# 2      78  Standard query 0x0000  SRV _domain._udp.local,...
# 3      60              Who has 10.10.10.1?  Tell 10.10.10.15
# 4      60                 10.10.10.1 is at 00:50:04:68:a6:95

# %%
rhpass["Type"] = rhpass.apply(lambda x: "Client" if x["Source"] == rhpass.irow(0)["Source"] else "Server", axis=1)

# %%
rhpass.head()
# Out:
#    No.                Time             Source        Destination Protocol  \
# 0    1 2011-11-18 10:42:32        10.10.10.15       10.10.10.255  BROWSER
# 1    2 2011-11-18 10:43:14      3com_68:a6:95          Broadcast      ARP
# 2    3 2011-11-18 10:43:46        10.10.10.10        224.0.0.251     MDNS
# 3    4 2011-11-18 10:44:04  Tp-LinkT_b5:79:3f          Broadcast      ARP
# 4    5 2011-11-18 10:44:04      3com_68:a6:95  Tp-LinkT_b5:79:3f      ARP
#
#    Length                                               Info    Type
# 0     243  Local Master Announcement XP, Workstation, Ser...  Client
# 1      60              Who has 10.10.10.10?  Tell 10.10.10.1  Server
# 2      78  Standard query 0x0000  SRV _domain._udp.local,...  Server
# 3      60              Who has 10.10.10.1?  Tell 10.10.10.15  Server
# 4      60                 10.10.10.1 is at 00:50:04:68:a6:95  Server

# %%
infodata2 = rhpass[['Length','Time','Info']]
infodata2.head()
# Out:
#    Length                Time  \
# 0     243 2011-11-18 10:42:32
# 1      60 2011-11-18 10:43:14
# 2      78 2011-11-18 10:43:46
# 3      60 2011-11-18 10:44:04
# 4      60 2011-11-18 10:44:04
#
#                                                 Info
# 0  Local Master Announcement XP, Workstation, Ser...
# 1              Who has 10.10.10.10?  Tell 10.10.10.1
# 2  Standard query 0x0000  SRV _domain._udp.local,...
# 3              Who has 10.10.10.1?  Tell 10.10.10.15
# 4                 10.10.10.1 is at 00:50:04:68:a6:95

# %%
infodata2 = infodata2.set_index('Time')
infodata2.head()
# Out:
#                      Length                                               Info
# Time
# 2011-11-18 10:42:32     243  Local Master Announcement XP, Workstation, Ser...
# 2011-11-18 10:43:14      60              Who has 10.10.10.10?  Tell 10.10.10.1
# 2011-11-18 10:43:46      78  Standard query 0x0000  SRV _domain._udp.local,...
# 2011-11-18 10:44:04      60              Who has 10.10.10.1?  Tell 10.10.10.15
# 2011-11-18 10:44:04      60                 10.10.10.1 is at 00:50:04:68:a6:95

# %%
infodata2.resample('T',how=sum).head()
# Out:
#                       Length
# Time
# 2011-11-18 10:42:00      243
# 2011-11-18 10:43:00      138
# 2011-11-18 10:44:00   685360
# 2011-11-18 10:45:00  1081151
# 2011-11-18 10:46:00  3655982

# %%
infodata2_plot = infodata2.resample('T',how=sum).plot(kind="barh",title="Frequency Attack freebsd tcpdump",figsize=(20,20),legend=True)

# %%
fig = infodata2_plot.get_figure()
fig.savefig("Frekuensi Freebsd attack.png")

# %%
rhpass.head()
# Out:
#    No.                Time             Source        Destination Protocol  \
# 0    1 2011-11-18 10:42:32        10.10.10.15       10.10.10.255  BROWSER
# 1    2 2011-11-18 10:43:14      3com_68:a6:95          Broadcast      ARP
# 2    3 2011-11-18 10:43:46        10.10.10.10        224.0.0.251     MDNS
# 3    4 2011-11-18 10:44:04  Tp-LinkT_b5:79:3f          Broadcast      ARP
# 4    5 2011-11-18 10:44:04      3com_68:a6:95  Tp-LinkT_b5:79:3f      ARP
#
#    Length                                               Info    Type
# 0     243  Local Master Announcement XP, Workstation, Ser...  Client
# 1      60              Who has 10.10.10.10?  Tell 10.10.10.1  Server
# 2      78  Standard query 0x0000  SRV _domain._udp.local,...  Server
# 3      60              Who has 10.10.10.1?  Tell 10.10.10.15  Server
# 4      60                 10.10.10.1 is at 00:50:04:68:a6:95  Server

# %%
category_group=rhpass.groupby(['Source','Destination','Protocol']).sum()
category_group.head()
# Out:
#                                          No.    Length
# Source      Destination Protocol
# 10.10.10.1  10.10.10.15 TCP          1202354       180
# 10.10.10.10 10.10.10.15 HTTP      7085600807  19434592
#                         ICMP      4973287699   2540874
#                         IPv4      9788553673  18697522
#                         MDNS          134173       881

# %%
my_plot = category_group.plot(kind='barh',stacked=True,title="Frequency Attack Freebsd TCPDUMP",figsize=(25,50))
my_plot.set_xlabel("Length Protocol")
my_plot.set_ylabel("Source IP - Destination IP")

# %%
fig = infodata2_plot.get_figure()
fig.savefig("Frequency Attack Freebsd TCPDUMP.png")

# %%
my_plot = category_group.unstack().plot(kind='barh',stacked=True,title="Total Protocol",figsize=(20, 20))
my_plot.set_xlabel("Frekuensi Protocol")
my_plot.set_ylabel("IP address")
patches, labels = my_plot.get_legend_handles_labels()
my_plot.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=8, title="Protocol")
